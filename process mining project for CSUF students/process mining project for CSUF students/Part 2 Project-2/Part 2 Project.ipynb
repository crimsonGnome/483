# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pm4py==2.1.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pm4py==2.1.2 in /usr/local/lib/python3.7/dist-packages (2.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.7.1)
# Requirement already satisfied: pyvis in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (0.2.1)
# Requirement already satisfied: numpy<=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.19.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (3.2.2)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.6.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2022.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (4.64.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (4.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.0.2)
# Requirement already satisfied: pm4pycvxopt>=0.0.10 in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (0.0.10)
# Requirement already satisfied: stringdist in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.0.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (1.7.3)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.1.0)
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.1.0)
# Requirement already satisfied: pulp<=2.1 in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (0.10.1)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (from pm4py==2.1.2) (2.0.2)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from pm4pycvxopt>=0.0.10->pm4py==2.1.2) (1.3.0)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pulp<=2.1->pm4py==2.1.2) (3.0.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->pm4py==2.1.2) (21.3)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from intervaltree->pm4py==2.1.2) (2.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonpickle->pm4py==2.1.2) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle->pm4py==2.1.2) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle->pm4py==2.1.2) (4.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pm4py==2.1.2) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pm4py==2.1.2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pm4py==2.1.2) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->pm4py==2.1.2) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from pyvis->pm4py==2.1.2) (7.9.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.7/dist-packages (from pyvis->pm4py==2.1.2) (2.11.3)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.18.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9.6->pyvis->pm4py==2.1.2) (2.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython>=5.3.0->pyvis->pm4py==2.1.2) (0.7.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pm4py==2.1.2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pm4py==2.1.2) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->pm4py==2.1.2) (1.2.1)

# %%
import os

# %%
#Changing the directory
os.chdir('/content/drive/My Drive/Process mining course/Part 2 Project')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import sklearn

from pydream.predictive.nap.NAP import NAP, multiclass_roc_auc_score
import pickle
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support,precision_score, recall_score, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

from pydream.EnhancedPN import EnhancedPN
from pm4py.objects.petri.importer import importer as pnml_importer
from backend.stat.ci_auc import calculate_auc_ci

# %%
train_json = "tss_heart_log_train0.json"
valid_json ="tss_heart_log_val0.json"
test_json = "tss_heart_log_test0.json"

# %%
train_algo = NAP(tss_train_file=train_json, tss_test_file=valid_json, options={"n_epochs" : 2})
train_algo.train(checkpoint_path="chk_points", name="HF_model", save_results=True)
# Out:
# Xtrain shape: (8403, 1920)
# X2train shape: (8403, 3)
# Severity train shape: (8403, 58)
# X2test shape: (1531, 3)
# Xtest shape: (1531, 1920)
# Severity test shape: (1531, 58)
# Ytrain shape: (8403, 2)
# Ytest shape: (1531, 2)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Class weights :  <module 'sklearn.utils.class_weight' from '/usr/local/lib/python3.7/dist-packages/sklearn/utils/class_weight.py'>
# Train on 8403 samples, validate on 1531 samples
# Epoch 1/2
# 8370/8403 [============================>.] - ETA: 0s - loss: 0.8460 - acc: 0.1633
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# test_prec_mean 0.08001306335728282
# test_rec_mean 0.5
# test_fscore_mean 0.13795045045045046
# test_auc_mean 0.5
#
# Epoch 1: test_rec_mean improved from -inf to 0.50000, saving model to chk_points/HF_model_split_weights.hdf5
# 8403/8403 [==============================] - 13s 2ms/sample - loss: 0.8454 - acc: 0.1630 - val_loss: 1.3590 - val_acc: 0.1600 - test_acc: 0.1600 - test_prec_weighted: 0.0256 - test_rec_weighted: 0.1600 - test_loss: 1.3590 - test_fscore_weighted: 0.0442 - test_auc_weighted: 0.5000 - test_prec_mean: 0.0800 - test_rec_mean: 0.5000 - test_fscore_mean: 0.1380 - test_auc_mean: 0.5000 - lr: 0.0010
# Epoch 2/2
# 8403/8403 [==============================] - ETA: 0s - loss: 0.8061 - acc: 0.1591test_prec_mean 0.08001306335728282
# test_rec_mean 0.5
# test_fscore_mean 0.13795045045045046
# test_auc_mean 0.5
#
# Epoch 2: test_rec_mean did not improve from 0.50000
# 8403/8403 [==============================] - 12s 1ms/sample - loss: 0.8061 - acc: 0.1591 - val_loss: 1.3158 - val_acc: 0.1600 - test_acc: 0.1600 - test_prec_weighted: 0.0256 - test_rec_weighted: 0.1600 - test_loss: 1.3158 - test_fscore_weighted: 0.0442 - test_auc_weighted: 0.5000 - test_prec_mean: 0.0800 - test_rec_mean: 0.5000 - test_fscore_mean: 0.1380 - test_auc_mean: 0.5000 - lr: 0.0010

# %%
algo = NAP()
algo.loadModel(path="chk_points", name="HF_model")

X_test, X2_test, severity_test, Y_test = algo.loadData(test_json)

# %%
stdScaler = MinMaxScaler()
stdScaler.fit(X_test)
X_test = stdScaler.transform(X_test)
stdScaler.fit(X2_test)
X2_test = stdScaler.transform(X2_test)
stdScaler.fit(severity_test)
severity_test = stdScaler.transform(severity_test)

Y_test_int = np.array([int(i) for i in Y_test])
y_prob = algo.model.predict([X_test,X2_test,severity_test])
y_pred = np.argmax(y_prob, axis=1)

test_acc = accuracy_score(Y_test_int, y_pred, normalize=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
y_true =Y_test_int
y_probscore = []
list_of_lists = []
for x in y_prob:
    list_of_lists.append(list(x))
    y_probscore.append(list(x)[1])


y_score = np.array(y_probscore)
y_pred = np.around(y_pred)
y_true = np.array(y_true)
auc, auc_cov, ci = calculate_auc_ci(y_true,y_score,y_pred, alpha=0.95)
print("AUC Score: ",auc)
print("AUC_cov: ", auc_cov)
print("confidence interval: ",ci)
# Out:
# *** Confusion Matrix ***
# true\pred     0     1
#         0   0.0 237.0
#         1   0.0  57.0
#
# AUC Score:  0.6782885483751573
# AUC_cov:  0.0016566756877991525
# confidence interval:  [0.59851354 0.75806355]
